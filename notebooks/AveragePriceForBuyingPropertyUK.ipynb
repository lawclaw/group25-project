# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('../data/Average-prices-2023-04.csv')
df
# Out:
#               Date                Region_Name  Area_Code  Average_Price  \
# 0       1968-04-01           Northern Ireland  N92000001    3661.485500
# 1       1968-04-01                    England  E92000001    3408.108064
# 2       1968-04-01                      Wales  W92000004    2885.414162
# 3       1968-04-01                   Scotland  S92000003    2844.980688
# 4       1968-04-01                     London  E12000007    4418.489911
# ...            ...                        ...        ...            ...
# 136120  2023-04-01  Cheshire West and Chester  E06000050  263450.673900
# 136121  2023-04-01                 Shropshire  E06000051  272540.793400
# 136122  2023-04-01          England and Wales  K04000001  300635.526900
# 136123  2023-04-01              Great Britain  K03000001  289759.855100
# 136124  2023-04-01             United Kingdom  K02000001  286488.877000
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# ...

# %%
df1968= df.loc[df['Region_Name'] == "England"]
df1968
# Out:
#               Date Region_Name  Area_Code  Average_Price  Monthly_Change  \
# 1       1968-04-01     England  E92000001    3408.108064        0.000000
# 10      1968-05-01     England  E92000001    3408.108064        0.000000
# 22      1968-06-01     England  E92000001    3408.108064        0.000000
# 30      1968-07-01     England  E92000001    3524.293566        3.409091
# 43      1968-08-01     England  E92000001    3524.293566        3.409091
# ...            ...         ...        ...            ...             ...
# 134103  2022-12-01     England  E92000001  310960.104800       -0.195285
# 134506  2023-01-01     England  E92000001  308565.350700       -0.770116
# 134912  2023-02-01     England  E92000001  307975.478100       -0.191166
# 135315  2023-03-01     England  E92000001  304173.479700       -1.234513
# 135721  2023-04-01     England  E92000001  305730.792800        0.511982
#
#         Annual_Change  Average_Price_SA
# 1                 NaN               NaN
# ...

# %%
df1968.to_excel('../data/processed/england_1968.xlsx')
df.to_excel('../data/processed/averagePropertyPricesUK.xlsx')

# %%
dfType = pd.read_csv('../data/Average-prices-Property-Type-2023-04.csv')
dfType
# Out:
#               Date                Region_Name  Area_Code
# 0       1995-01-01                    England  E92000001  \
# 1       1995-01-01                      Wales  W92000004
# 2       1995-01-01               Inner London  E13000001
# 3       1995-01-01               Outer London  E13000002
# 4       1995-01-01                     London  E12000007
# ...            ...                        ...        ...
# 130043  2023-04-01  Cheshire West and Chester  E06000050
# 130044  2023-04-01                 Shropshire  E06000051
# 130045  2023-04-01          England and Wales  K04000001
# 130046  2023-04-01              Great Britain  K03000001
# 130047  2023-04-01             United Kingdom  K02000001
#
#         Detached_Average_Price  Detached_Index  Detached_Monthly_Change
# 0                  86314.15895       28.257874                      NaN  \
# 1                  66539.58684       32.491063                      NaN
# ...

# %%
dfType.to_excel('./data/averagePricePerType.xlsx')
