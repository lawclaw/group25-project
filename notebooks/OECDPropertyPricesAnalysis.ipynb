# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/PropertyPricesForEachCountryEachQuarter.csv') # File is Property Prices for each countries in the world each quarter
df = df.dropna(axis='columns')
df.sort_values('2018-Q1')
df.to_excel('output.xlsx')
df
# Out:
#    FREQ  Frequency REF_AREA  Reference area Time Period   1991-Q1   1991-Q2  \
# 0     Q  Quarterly       AU       Australia        Q:AU   89.2978   90.3677
# 1     Q  Quarterly       BE         Belgium        Q:BE   78.9600   77.7800
# 2     Q  Quarterly       CA          Canada        Q:CA   97.4700  100.9300
# 3     Q  Quarterly       CH     Switzerland        Q:CH  112.5025  113.2979
# 4     Q  Quarterly       DE         Germany        Q:DE   85.2098   86.8477
# 5     Q  Quarterly       DK         Denmark        Q:DK   84.2021   85.2621
# 6     Q  Quarterly       ES           Spain        Q:ES   92.7000   96.4000
# 7     Q  Quarterly       FI         Finland        Q:FI  135.5966  133.6167
# 8     Q  Quarterly       FR          France        Q:FR  102.7100  104.8500
# 9     Q  Quarterly       GB  United Kingdom        Q:GB  101.9892  101.6275
# 10    Q  Quarterly       HK   Hong Kong SAR        Q:HK   46.2255   52.1901
# ...

# %%
x = df['Reference area']
y = df['2018-Q2']
plt.figure(figsize = (40,8))

plt.plot(x,y)
plt.plot(x,y, 'o')
