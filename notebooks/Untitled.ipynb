# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./Live_Table_704_Jan_23.ods', engine='odf', header=[2])
df = df[df['CurrentONS code'].notna()]
df = df[df['Lower and Single Tier Authority Data'].notna()]
df
# Out:
#     Unnamed: 0 CurrentONS code Lower and Single Tier Authority Data   1997  \
# 5          NaN       E07000157                              Alnwick  36.99
# 6          NaN       E07000158                   Berwick-upon-Tweed  40.11
# 7          NaN       E07000159                         Blyth Valley  39.51
# 8          NaN       E07000160                       Castle Morpeth  38.96
# 9          NaN       E07000054                    Chester-le-Street  38.19
# ..         ...             ...                                  ...    ...
# 396        NaN       E07000052                          West Dorset   47.7
# 397        NaN       E07000191                        West Somerset  52.32
# 398        NaN       E07000233                       West Wiltshire  49.13
# 399        NaN       E07000053                Weymouth and Portland  51.12
# 400        NaN       E06000054                            Wiltshire     ..
#
# ...

# %%
cols = ['CurrentONS code', 'Lower and Single Tier Authority Data']
for i in range(2008, 2020):
    cols.append(i)
recentDf = df[cols]

# %%
recentDf.to_excel('./data/processed/privateWeeklyRent.xlsx')
